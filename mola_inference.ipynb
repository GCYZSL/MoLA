# %%
import os
import argparse
import random

import torch
from src.mola_peft_model_hacked import PeftModel
from transformers import GenerationConfig, LlamaTokenizer, AutoConfig
import sys
from src.mola_modeling_llama_hacked import LlamaForCausalLM_d

if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

try:
    if torch.backends.mps.is_available():
        device = "mps"
except:  # noqa: E722
    pass

seed = 10
random.seed(seed)  # random seed
torch.manual_seed(0)

# %%
input_text = "Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\nContext: Hint: People who can knit had to learn how to do it.\nQuestion: Is the following trait inherited or acquired?\nSasha is good at knitting hats.\nOptions: (A) acquired (B) inherited\n\n\n### Response:\n"

### MoLA config
base_model = "NousResearch/Llama-2-7b-hf"
mola_weights = "./scienceqa_mola"
number_experts = "2,2,2,2,2,2,2,2,4,4,4,4,4,4,4,4,6,6,6,6,6,6,6,6,8,8,8,8,8,8,8,8"
top_k = "2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2"
lora_target_modules = "q_proj,v_proj,k_proj,o_proj,gate_proj,down_proj,up_proj"

### Generation Config
temperature = 0.1
top_p = 0.75
top_k_g = 20

# %%
lora_target_modules = lora_target_modules.split(",")
lora_target_modules = [str(lr) for lr in lora_target_modules]
number_experts = number_experts.split(",")
number_experts = [int(lr) for lr in number_experts]
top_k = top_k.split(",")
top_k = [int(lr) for lr in top_k]

load_8bit = False

tokenizer = LlamaTokenizer.from_pretrained(base_model, padding_side='left')
config = AutoConfig.from_pretrained(base_model)
config.lora_target_modules = lora_target_modules
if device == "cuda":
    model = LlamaForCausalLM_d.from_pretrained(
        base_model,
        config=config,
        load_in_8bit=load_8bit,
        torch_dtype=torch.float16,
        device_map="auto",
    )
    model = PeftModel.from_pretrained(
        model,
        mola_weights,
        torch_dtype=torch.float16,
        number_experts=number_experts,
        top_k=top_k,
    )
else:
    model = LlamaForCausalLM_d.from_pretrained(
        base_model, config=config, device_map={"": device}, low_cpu_mem_usage=True
    )
    model = PeftModel.from_pretrained(
        model,
        mola_weights,
        device_map={"": device},
    )
obalance = False
model.get_new_parameters(number_experts, top_k, obalance)

print(model.config.pad_token_id, tokenizer.pad_token_id)
print(model.config.bos_token_id, tokenizer.bos_token_id)
print(model.config.eos_token_id, tokenizer.eos_token_id)
# unwind broken decapoda-research config
model.config.pad_token_id = tokenizer.pad_token_id = 0  # unk
model.config.bos_token_id = 1
model.config.eos_token_id = 2

if not load_8bit:
    model.half()  # seems to fix bugs for some users.

model.eval()
if torch.__version__ >= "2" and sys.platform != "win32":
    model = torch.compile(model)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# TRAINING MOLA
# load----- base_model.model.model.layers.0.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.0.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.0.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.0.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.0.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.0.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.0.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.1.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.1.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.1.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.1.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.1.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.1.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.1.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.2.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.2.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.2.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.2.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.2.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.2.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.2.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.3.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.3.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.3.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.3.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.3.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.3.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.3.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.4.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.4.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.4.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.4.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.4.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.4.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.4.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.5.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.5.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.5.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.5.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.5.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.5.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.5.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.6.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.6.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.6.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.6.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.6.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.6.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.6.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.7.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.7.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.7.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.7.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.7.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.7.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.7.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.8.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.8.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.8.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.8.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.8.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.8.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.8.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.9.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.9.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.9.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.9.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.9.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.9.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.9.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.10.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.10.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.10.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.10.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.10.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.10.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.10.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.11.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.11.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.11.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.11.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.11.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.11.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.11.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.12.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.12.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.12.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.12.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.12.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.12.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.12.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.13.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.13.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.13.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.13.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.13.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.13.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.13.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.14.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.14.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.14.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.14.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.14.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.14.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.14.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.15.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.15.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.15.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.15.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.15.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.15.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.15.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.16.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.16.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.16.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.16.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.16.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.16.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.16.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.17.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.17.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.17.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.17.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.17.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.17.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.17.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.18.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.18.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.18.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.18.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.18.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.18.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.18.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.19.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.19.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.19.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.19.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.19.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.19.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.19.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.20.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.20.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.20.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.20.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.20.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.20.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.20.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.21.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.21.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.21.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.21.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.21.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.21.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.21.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.22.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.22.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.22.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.22.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.22.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.22.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.22.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.23.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.23.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.23.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.23.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.23.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.23.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.23.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.24.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.24.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.24.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.24.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.24.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.24.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.24.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.25.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.25.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.25.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.25.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.25.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.25.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.25.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.26.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.26.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.26.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.26.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.26.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.26.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.26.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.27.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.27.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.27.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.27.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.27.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.27.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.27.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.28.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.28.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.28.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.28.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.28.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.28.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.28.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.29.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.29.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.29.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.29.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.29.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.29.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.29.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.30.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.30.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.30.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.30.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.30.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.30.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.30.mlp.up_proj.router.router.weight
# load----- base_model.model.model.layers.31.self_attn.q_proj.router.router.weight
# load----- base_model.model.model.layers.31.self_attn.k_proj.router.router.weight
# load----- base_model.model.model.layers.31.self_attn.v_proj.router.router.weight
# load----- base_model.model.model.layers.31.self_attn.o_proj.router.router.weight
# load----- base_model.model.model.layers.31.mlp.gate_proj.router.router.weight
# load----- base_model.model.model.layers.31.mlp.down_proj.router.router.weight
# load----- base_model.model.model.layers.31.mlp.up_proj.router.router.weight
# NEW PARAMETERS obalance False
# 0 0
# 1 1
# 2 2

# %%
max_new_tokens = 128

generation_config = GenerationConfig(
    temperature=temperature,
    top_p=top_p,
    top_k=top_k_g,
)
inputs = tokenizer(input_text, return_tensors="pt")
input_ids = inputs["input_ids"].to(device)
with torch.no_grad():
    generation_output = model.generate(
        input_ids=input_ids,
        generation_config=generation_config,
        return_dict_in_generate=True,
        output_scores=True,
        max_new_tokens=max_new_tokens,
    )
s = generation_output.sequences[0]
output = tokenizer.decode(s)
print(output)
# Out:
# <s> Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Context: Hint: People who can knit had to learn how to do it.
# Question: Is the following trait inherited or acquired?
# Sasha is good at knitting hats.
# Options: (A) acquired (B) inherited
#
#
# ### Response:
# Answer: The answer is A.</s>
